# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='AppleGothic')
plt.rc('axes',unicode_minus=False)
# %matplotlib inline

# %%
df=pd.read_csv("Data/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory=False)

# %%
#seaborn은 대체로 x, y, data를 기본으로 넣어줘야 하지만 countplot은 x,y 중 하나만 넣어도 O
sns.countplot(data=df,y='시도명')
# Out:
# <AxesSubplot:xlabel='count', ylabel='시도명'>

# %%
#그래프로 그리는 데이터 가공
df["상권업종대분류명"].value_counts()
# Out:
# 의료    91335
# Name: 상권업종대분류명, dtype: int64

# %%
n = df["상권업종중분류명"].value_counts(normalize=True)
n
# Out:
# 병원          0.665397
# 약국/한약방      0.229080
# 수의업         0.058280
# 유사의료업       0.041320
# 의료관련서비스업    0.005923
# Name: 상권업종중분류명, dtype: float64

# %%
c = df["상권업종중분류명"].value_counts()
c
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
c.plot.bar(figsize=(7,8), grid=True)
# Out:
# <AxesSubplot:>

# %%
n.plot.pie()
# Out:
# <AxesSubplot:ylabel='상권업종중분류명'>
