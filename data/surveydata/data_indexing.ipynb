# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Data/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory=False)

# %%
df["상권업종중분류명"] == "약국/한약방"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 91330     True
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종중분류명, Length: 91335, dtype: bool

# %%
df[df["상권업종중분류명"] == "약국/한약방"].head()
# Out:
#       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 4   20364049  더블유스토어수지점  수지점         S       의료       S02   약국/한약방    S02A01
# 6   20733252      춘산한약방  NaN         S       의료       S02   약국/한약방    S02A02
# 7   20582210      부부탕제원  NaN         S       의료       S02   약국/한약방    S02A03
# 10  21057519       민생약국  NaN         S       의료       S02   약국/한약방    S02A01
# 13  21217689     제중당한약방  NaN         S       의료       S02   약국/한약방    S02A02
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 4        약국   G47811  ...  4146510100107120002026238  NaN
# 6       한약방   G47811  ...  4211010500101000000023668  NaN
# 7       탕제원   G47859  ...  4311112000101870017042942  NaN
# 10       약국   G47811  ...  4889046030200780002048274  NaN
# 13      한약방   G47811  ...  4683035023102960000000001  NaN
#
#                          도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
df_medical = df[df["상권업종중분류명"] == "약국/한약방"].copy()

# %%
df[df["상권업종대분류명"] == "의료"].head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  19956873     하나산부인과  NaN         S       의료       S01       병원    S01B10
# 1  20024149   타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 2  20152277  조정현신경외과의원  NaN         S       의료       S01       병원    S01B15
# 3  20350610   한귀원정신과의원  NaN         S       의료       S01       병원    S01B99
# 4  20364049  더블유스토어수지점  수지점         S       의료       S02   약국/한약방    S02A01
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0     산부인과   Q86201  ...  4127310900110810000010857  산호한양아파트
# 1    내과/외과   Q86201  ...  1168011800104670014000001      NaN
# 2     신경외과   Q86201  ...  4139013200117400001017064    한라프라자
# 3     기타병원      NaN  ...  2650010400100740001009932      NaN
# 4       약국   G47811  ...  4146510100107120002026238      NaN
#
#                  도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
df.loc[df["상권업종대분류명"] == "의료"]["상권업종중분류명"]
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
df.loc[df["상권업종대분류명"] == "의료", "상권업종중분류명"] #빠른 속도
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
m = df["상권업종대분류명"] == "의료"
df.loc[m, "상권업종중분류명"].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
df["상권업종중분류명"] ==  "유사의료업"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종중분류명, Length: 91335, dtype: bool

# %%
df[df["상권업종중분류명"] ==  "유사의료업"]
# Out:
#          상가업소번호         상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 22     21013731    세종언어치료센터    NaN         S       의료       S03    유사의료업
# 40     20933900     고려수지침학회    NaN         S       의료       S03    유사의료업
# 97     21717820         청명원    NaN         S       의료       S03    유사의료업
# 102    21865854    응급환자이송센터    NaN         S       의료       S03    유사의료업
# 108    21914637  태화아동발달지원센터    NaN         S       의료       S03    유사의료업
# ...         ...         ...    ...       ...      ...       ...      ...
# 91300  16131218     으뜸치과기공소    NaN         S       의료       S03    유사의료업
# 91310  16199325     보령치과기공소    NaN         S       의료       S03    유사의료업
# 91311  16199088       점프셈교실   홍현단과         S       의료       S03    유사의료업
# 91319  16108560  씨앤디자인치과기공소    NaN         S       의료       S03    유사의료업
# 91327  16190388       오피스알파  치과기공소         S       의료       S03    유사의료업
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
df["상호명"].value_counts().tail()
# Out:
# 둘리소아과의원        1
# 그랄나무병원         1
# 유플랜트치과         1
# 오제기공소          1
# 에이치드림정형외과의원    1
# Name: 상호명, dtype: int64

# %%
df["상호명"].value_counts().head(10)
# Out:
# 리원       152
# 온누리약국    149
# 경희한의원    141
# 우리약국     119
# 중앙약국     111
# 전자담배      98
# 조은약국      95
# 건강약국      87
# 제일약국      79
# 사랑약국      73
# Name: 상호명, dtype: int64

# %%
(df["상권업종소분류명"] == "약국") & (df["시도명"] == "서울특별시")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Length: 91335, dtype: bool

# %%
df_seoul_drug = (df["상권업종소분류명"] == "약국") & (df["시도명"] == "서울특별시")
df_seoul_drug
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Length: 91335, dtype: bool

# %%
df_seoul_hospital = df[(df["상권업종소분류명"] == "종합병원") & (df["시도명"] == "서울특별시")].copy()

# %%
df_seoul_hospital.head()
# Out:
#         상가업소번호               상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 305   25155642            대진의료재단  NaN         S       의료       S01       병원
# 353   20471487            홍익병원별관  NaN         S       의료       S01       병원
# 385   20737057              SNUH  NaN         S       의료       S01       병원
# 1917  23210677  평화드림여의도성모병원의료기매장  NaN         S       의료       S01       병원
# 2461  20024045                한양  NaN         S       의료       S01       병원
#
#      상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호        건물명  \
# 305     S01B01     종합병원   Q86101  ...  1121510100100580025000733  재단법인대순진리회
# 353     S01B01     종합병원   Q86101  ...  1147010100108970013001044     홍익병원별관
# 385     S01B01     종합병원   Q86101  ...  1168010100107360055027688       성보빌딩
# 1917    S01B01     종합병원   Q86101  ...  1156011000100620000031477    여의도성모병원
# 2461    S01B01     종합병원   Q86101  ...  1120010700100150001019623     한대동문회관
#
# ...
